# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import statsmodels.api as sm
import regex as re
import plotly.express as px
import requests
from bs4 import BeautifulSoup as BS
from io import StringIO
# %matplotlib inline

# %% [markdown]
# ## Read in data from Wikipedia page
#
# Using pd.read_html : https://www.marsja.se/how-to-use-pandas-read_html-to-scrape-data-from-html-tables/

# %%
url = 'https://en.wikipedia.org/wiki/List_of_deadly_earthquakes_since_1900'

# %%
wiki_page = pd.read_html(url)

# %%
type(wiki_page)
# Out:
# list

# %%
#discern how many tables there are in the HTML code for the page
len(wiki_page)
# Out:
# 5

# %%
#access the table and save it to variable
wiki=wiki_page[4]

# %%
#verify data type
type(wiki)
# Out:
# pandas.core.frame.DataFrame

# %%
wiki.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1340 entries, 0 to 1339
# Data columns (total 12 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Origin (UTC)                                       1340 non-null   object
#  1   Present-day country and link to Wikipedia article  1340 non-null   object
#  2   Lat                                                1325 non-null   object
#  3   Long                                               1325 non-null   object
#  4   Depth (km)                                         1250 non-null   object
#  5   Magnitude                                          1339 non-null   object
#  6   Secondary Effects                                  373 non-null    object
#  7   PDE Shaking Deaths                                 738 non-null    float64
#  8   PDE Total Deaths                                   749 non-null    float64
#  9   Utsu Total Deaths                                  1027 non-null   float64
#  10  EM-DAT Total Deaths                                559 non-null    object
#  11  Other Source Deaths                                37 non-null     object
# dtypes: float64(3), object(9)
# memory usage: 125.8+ KB

# %% [markdown]
# ## Cleaning the data

# %% [markdown]
# #### Rename columns

# %%
#rename columns
wiki = wiki.rename(columns={"Origin (UTC)":"origin", "Present-day country and link to Wikipedia article":"country",
       "Lat":"lat", "Long":"long", "Depth (km)":"depth_km", "Magnitude":"magnitude", "Secondary Effects":"secondary_effects",
       "PDE Shaking Deaths":"pde_shaking_deaths", "PDE Total Deaths":"pde_total_deaths", "Utsu Total Deaths":"utsu_total_deaths",
       "EM-DAT Total Deaths":"emdat_total_deaths", "Other Source Deaths":"other_source_deaths"})

# %% [markdown]
# #### Locate and remove footnote notations. eg: '8.8 Mw [18]'

# %%
wiki[['magnitude','emdat_total_deaths', 'other_source_deaths']]= wiki[['magnitude','emdat_total_deaths', 'other_source_deaths']].apply(lambda x: x.str.replace('( \[\d{1,2}\])',''), axis=1)

# %% [markdown]
# #### Locate and remove "(see....)" in country column & clean up country names

# %%
wiki['country']= wiki['country'].str.replace(
    '( \(.*\)?)','').str.replace(
    '(\(see 1997 Cariaco earthquake\))','Venezuela').str.replace(
    '(Iran, 2005 Qeshm earthquake)','Iran').str.replace(
    'US Territory of Alaska','United States').str.replace(
    'Mandatory Palestine and Transjordan','Palestine').str.replace(
    'Burma','Myanmar').str.replace(
    'Tajik Soviet Socialist Republic','Tajikistan').str.replace(
    'Kingdom of Yugoslavia','Yugoslavia'
)

# %% [markdown]
# #### Deaths - calculate the greatest number of deaths reported for each event.

# %%
#Alvin's version
# delete other sources column
#del wiki['other_source_deaths']

# %%
#Remove footnotes bracket from other_source_deaths & emdat_total_deaths column. In cells where there is more than one value noted, it also occurs with footnotes. Keep only the first value.
wiki['other_source_deaths']= wiki['other_source_deaths'].str.replace(
    '(\*|\+)','').str.replace('(\[\d{1,2}\]?.*)','').str.replace('(( .*))','').str.replace('(,)','')
                                                                                                            
wiki['emdat_total_deaths']= wiki['emdat_total_deaths'].str.replace('(\[\d{1,2}\]?.*)','')

# %%
#change to numeric
wiki[['other_source_deaths','emdat_total_deaths']]=wiki[['other_source_deaths','emdat_total_deaths']].apply(pd.to_numeric)

# %%
#wiki[['other_source_deaths','emdat_total_deaths']]=wiki[['other_source_deaths','emdat_total_deaths']].astype(float)

# %%
# new column for largest death in column
wiki['deaths'] = wiki[['pde_shaking_deaths', 'pde_total_deaths',
       'utsu_total_deaths', 'emdat_total_deaths','other_source_deaths']].max(axis=1)

# %% [markdown]
# #### Split magnitude column on delimiter to create two columns for magnitude value and magnitude scale

# %%
wiki[['magnitude','magnitude_scale']]= wiki['magnitude'].str.split(' ', n=1, expand=True)

# %%
#Alvin's version run in lieu of removing footnote notations
#split on space to create new columns (there is third column because second blank space occurred for footnotes...deleted in code below)
#wiki[['magnitude','measure','del']] = wiki['magnitude'].str.split(' ',expand=True)

#created three columns deleted non essential
#del wiki['del']

# %% [markdown]
# #### Convert 'origin' column to datetime

# %%
wiki['origin'] = pd.to_datetime(wiki['origin'])

# %% [markdown]
# #### Change depth_km to numeric

# %%
#Remove ? and replace with NaN. Can't use str.replace in this case, need to use .replace and pass in argument regex=True
wiki['depth_km']=wiki['depth_km'].replace('\?', np.NaN, regex=True).astype(float)

# %% [markdown]
# #### Change magnitude to numeric

# %%
wiki['magnitude']=wiki['magnitude'].astype(float)

# %%
wiki.head()
# Out:
#              origin    country     lat     long  depth_km  magnitude  \
# 0  1900-05-11 17:23      Japan  38.700  141.100       5.0        7.0
# 1  1900-07-12 06:25     Turkey  40.300   43.100       NaN        5.9
# 2  1900-10-29 09:11  Venezuela  11.000  -66.000       0.0        7.7
# 3  1901-02-15 00:00      China  26.000  100.100       0.0        6.5
# 4  1901-03-31 07:11   Bulgaria  43.400   28.700       NaN        6.4
#
#   secondary_effects  pde_shaking_deaths  pde_total_deaths  utsu_total_deaths  \
# 0               NaN                 NaN               NaN                NaN
# 1               NaN                 NaN               NaN              140.0
# 2               NaN                 NaN               NaN                NaN
# 3               NaN                 NaN               NaN                NaN
# 4               NaN                 NaN               NaN                4.0
#
#    emdat_total_deaths  other_source_deaths  deaths magnitude_scale  year
# 0                 NaN                  NaN     NaN            MJMA  1900
# 1                 NaN                  NaN   140.0             Muk  1900
# 2                 NaN                  NaN     NaN              Mw  1900
# 3                 NaN                  NaN     NaN              Ms  1901
# 4                 NaN                  NaN     4.0             Muk  1901

# %% [markdown]
# ## What Factors Make Earthquakes More Likely?

# %%
fig = px.histogram(wiki, x="origin", histfunc='count',title='Frequency of Major Earthquakes Over Time')
fig.show()
# Out:
# <div>                            <div id="7b67e191-6419-41a8-a5ee-fd8190e6f985" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7b67e191-6419-41a8-a5ee-fd8190e6f985")) {                    Plotly.newPlot(                        "7b67e191-6419-41a8-a5ee-fd8190e6f985",                        [{"alignmentgroup": "True", "bingroup": "x", "histfunc": "count", "hovertemplate": "origin=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": ["1900-05-11T17:23:00", "1900-07-12T06:25:00", "1900-10-29T09:11:00", "1901-02-15T00:00:00", "1901-03-31T07:11:00", "1901-08-09T09:23:00", "1901-11-15T20:15:00", "1902-01-30T14:01:00", "1902-02-13T09:39:00", "1902-03-09T07:46:00", "1902-04-19T02:23:00", "1902-07-03T15:36:00", "1902-08-22T03:00:00", "1902-09-19T00:00:00", "1902-12-16T05:07:00", "1903-03-29T22:30:00", "1903-04-28T00:00:00", "1903-05-28T03:58:00", "1903-08-11T04:32:00", "1903-09-25T01:20:00", "1904-04-24T06:39:00", "1904-08-11T05:56:00", "1904-08-30T11:42:00", "1904-11-05T20:25:00", "1905-04-04T00:50:00", "1905-06-01T04:42:00", "1905-06-02T05:39:00", "1905-09-08T01:43:00", "1905-11-08T22:06:00", "1906-01-31T15:36:00", "1906-03-16T22:42:00", "1906-04-13T19:18:00", "1906-04-18T13:12:00", "1906-08-17T00:40:00", "1906-12-22T18:21:00", "1907-01-04T05:19:00", "1907-01-14T21:36:00", "1907-04-15T06:08:00", "1907-04-18T20:59:00", "1907-10-21T04:23:00", "1908-01-11T03:35:00", "1908-12-28T04:20:00", "1909-01-19T04:56:00", "1909-01-23T00:00:00", "1909-02-09T11:24:00", "1909-04-14T19:53:00", "1909-04-23T17:39:00", "1909-05-11T15:54:00", "1909-06-03T18:40:00", "1909-06-11T00:00:00", "1909-08-14T06:31:00", "1909-10-20T23:41:00", "1909-11-10T06:13:00", "1910-01-08T14:49:00", "1910-02-18T05:09:00", "1910-04-12T00:22:00", "1910-06-24T13:27:00", "1911-01-03T23:25:00", "1911-02-18T18:41:00", "1911-04-18T18:14:00", "1911-06-07T11:02:00", "1911-06-15T14:26:00", "1912-01-24T16:23:00", "1912-05-06T19:00:00", "1912-05-23T02:24:00", "1912-08-09T01:29:00", "1912-11-19T13:55:00", "1913-03-14T08:45:00", "1913-06-14T09:33:00", "1913-08-06T22:14:00", "1913-11-04T21:33:00", "1913-12-21T15:37:00", "1914-01-12T09:28:00", "1914-03-14T20:00:00", "1914-05-08T18:01:00", "1914-05-26T14:22:00", "1914-06-25T19:07:00", "1914-08-04T22:41:00", "1914-10-03T22:06:00", "1915-01-13T06:52:00", "1915-03-17T18:45:00", "1915-06-23T04:56:00", "1915-09-07T01:20:00", "1915-12-03T02:39:00", "1916-08-28T07:27:00", "1916-11-14T22:31:00", "1917-01-04T16:55:00", "1917-01-21T23:11:00", "1917-01-24T00:48:00", "1917-01-31T03:39:00", "1917-07-30T23:54:00", "1917-08-31T11:36:00", "1918-02-13T06:07:00", "1918-04-21T22:32:00", "1918-08-15T12:18:00", "1918-09-07T17:15:00", "1918-10-11T14:14:00", "1919-05-06T19:40:00", "1920-06-05T04:21:00", "1920-01-04T04:22:00", "1920-02-20T11:45:00", "1920-09-07T05:55:00", "1920-12-16T12:05:00", "1920-12-17T18:59:00", "1921-08-14T00:00:00", "1921-11-11T18:36:00", "1922-04-26T01:11:00", "1922-09-01T19:16:00", "1922-10-14T23:45:00", "1922-11-11T04:32:00", "1922-12-07T16:50:00", "1922-12-08T02:02:00", "1923-02-03T16:01:00", "1923-03-24T12:40:00", "1923-04-13T15:31:00", "1923-05-25T22:21:00", "1923-09-01T02:58:00", "1923-09-09T22:03:00", "1923-09-17T07:09:00", "1923-09-22T20:47:00", "1923-12-14T10:31:00", "1924-01-14T20:50:00", "1924-03-03T08:01:00", "1924-04-14T16:20:00", "1924-07-03T04:40:00", "1924-07-12T15:12:00", "1924-09-13T14:34:00", "1925-03-16T14:42:00", "1925-05-23T02:09:00", "1925-06-29T14:42:00", "1925-12-14T00:00:00", "1925-12-18T05:53:00", "1926-03-18T14:06:00", "1926-06-26T19:46:00", "1926-06-28T03:23:00", "1926-10-22T19:59:00", "1926-11-05T07:55:00", "1927-03-07T09:27:00", "1927-03-20T00:00:0 ...

# %%
death_size = wiki.dropna(subset=['deaths'], axis = 0)
fig = px.scatter(death_size, x='origin', y='magnitude',size='deaths',color='depth_km',hover_data=wiki, title='Earthquakes by Magnitude & Death Toll Over Time')
fig.show()
# Out:
# <div>                            <div id="a13e4c8f-ded5-4d72-9139-fd23450c78c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a13e4c8f-ded5-4d72-9139-fd23450c78c7")) {                    Plotly.newPlot(                        "a13e4c8f-ded5-4d72-9139-fd23450c78c7",                        [{"customdata": [["1900-07-12T06:25:00", "Turkey", "40.300", "43.100", null, 5.9, null, null, null, 140.0, null, null, 140.0, "Muk", 1900], ["1901-03-31T07:11:00", "Bulgaria", "43.400", "28.700", null, 6.4, null, null, null, 4.0, null, null, 4.0, "Muk", 1901], ["1901-11-15T20:15:00", "New Zealand", "-43.000", "173.000", 0.0, 6.8, null, null, null, 1.0, null, null, 1.0, "Ms", 1901], ["1902-01-30T14:01:00", "Japan", "40.500", "141.300", 35.0, 6.9, null, null, null, 1.0, null, null, 1.0, "Ms", 1902], ["1902-02-13T09:39:00", "Azerbaijan", "40.700", "48.600", 15.0, 6.9, null, null, null, 86.0, null, null, 86.0, "Muk", 1902], ["1902-03-09T07:46:00", "Turkey", "40.700", "33.600", null, 5.5, null, null, null, 4.0, null, null, 4.0, "Muk", 1902], ["1902-04-19T02:23:00", "Guatemala", "14.000", "-91.000", 0.0, 7.5, null, null, null, 2000.0, 2000.0, null, 2000.0, "Mw", 1902], ["1902-08-22T03:00:00", "China", "40.000", "77.000", 0.0, 7.7, null, null, null, 5650.0, null, null, 5650.0, "Mw", 1902], ["1902-09-19T00:00:00", "Australia", "-35.000", "138.000", 2.0, 6.0, null, null, null, 2.0, null, null, 2.0, "ML", 1902], ["1902-12-16T05:07:00", "Uzbekistan", "40.800", "72.300", 9.0, 6.4, null, null, null, 4725.0, null, null, 4725.0, "Muk", 1902], ["1903-03-29T22:30:00", "Palestine", "32.200", "35.300", null, 5.7, null, null, null, 20.0, null, null, 20.0, "Muk", 1903], ["1903-04-28T00:00:00", "Turkey", "39.14", "42.65", null, 7.0, null, null, null, null, null, 3500.0, 3500.0, "Ms", 1903], ["1903-05-28T03:58:00", "Turkey", "40.900", "42.700", null, 5.8, null, null, null, 1000.0, null, null, 1000.0, "Muk", 1903], ["1903-08-11T04:32:00", "Greece", "36.360", "22.970", 80.0, 8.3, null, null, null, 2.0, null, null, 2.0, "Muk", 1903], ["1903-09-25T01:20:00", "Iran", "35.200", "58.200", null, 6.5, null, null, null, 200.0, null, null, 200.0, "Muk", 1903], ["1904-04-24T06:39:00", "Taiwan", "23.500", "120.500", null, 6.0, null, null, null, 3.0, null, null, 3.0, "Muk", 1904], ["1904-08-11T05:56:00", "Greece", "37.750", "27.000", 10.0, 6.2, null, null, null, 4.0, null, null, 4.0, "Muk", 1904], ["1904-08-30T11:42:00", "China", "30.000", "101.000", 0.0, 6.8, null, null, null, 565.0, null, null, 565.0, "Ms", 1904], ["1904-11-05T20:25:00", "Taiwan", "23.500", "120.300", null, 6.3, null, null, null, 145.0, null, null, 145.0, "Muk", 1904], ["1905-04-04T00:50:00", "India", "33.000", "76.000", 0.0, 7.8, null, null, null, 20000.0, 20000.0, null, 20000.0, "Mw", 1905], ["1905-06-01T04:42:00", "Albania", "42.100", "19.600", 20.0, 6.6, null, null, null, 120.0, null, null, 120.0, "Muk", 1905], ["1905-06-02T05:39:00", "Japan", "34.100", "132.500", 55.0, 7.0, null, null, null, 11.0, null, null, 11.0, "mb", 1905], ["1905-09-08T01:43:00", "Italy", "39.000", "16.000", 0.0, 6.8, "T", null, null, 557.0, 2500.0, null, 2500.0, "Ms", 1905], ["1906-01-31T15:36:00", "Ecuador", "1.000", "-81.500", 0.0, 8.8, "T", null, null, 1000.0, 400.0, null, 1000.0, "Muk", 1906], ["1906-03-16T22:42:00", "Taiwan", "23.600", "120.400", 5.0, 6.8, null, null, null, 1258.0, null, null, 1258.0, "Ms", 1906], ["1906-04-13T19:18:00", "Taiwan", "23.600", "120.400", 5.0, 7.1, null, null, null, 15.0, null, null, 15.0, "MJMA", 1906], ["1906-04-18T13:12:00", "United States", "38.000", "-123.000", 0.0, 7.8, "F", null, null, 700.0, 2000.0, null, 2000.0, "Muk", 1906], ["1906-08-17T00:40:00", "Chile", "-33.000", "-72.000", 0.0, 8.2, "T", null, null, 3760.0, 20000.0, null, 20000.0, "Muk", 1906], [" ...

# %%
fig = px.scatter(wiki, x='magnitude', y='deaths',color='depth_km',hover_data=wiki, title='Magnitude & Deaths')
fig.show()
# Out:
# <div>                            <div id="3727b426-af37-43d8-b4f4-d22714178d15" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3727b426-af37-43d8-b4f4-d22714178d15")) {                    Plotly.newPlot(                        "3727b426-af37-43d8-b4f4-d22714178d15",                        [{"customdata": [["1900-07-12T06:25:00", "Turkey", "40.300", "43.100", null, 5.9, null, null, null, 140.0, null, null, 140.0, "Muk", 1900], ["1901-03-31T07:11:00", "Bulgaria", "43.400", "28.700", null, 6.4, null, null, null, 4.0, null, null, 4.0, "Muk", 1901], ["1901-11-15T20:15:00", "New Zealand", "-43.000", "173.000", 0.0, 6.8, null, null, null, 1.0, null, null, 1.0, "Ms", 1901], ["1902-01-30T14:01:00", "Japan", "40.500", "141.300", 35.0, 6.9, null, null, null, 1.0, null, null, 1.0, "Ms", 1902], ["1902-02-13T09:39:00", "Azerbaijan", "40.700", "48.600", 15.0, 6.9, null, null, null, 86.0, null, null, 86.0, "Muk", 1902], ["1902-03-09T07:46:00", "Turkey", "40.700", "33.600", null, 5.5, null, null, null, 4.0, null, null, 4.0, "Muk", 1902], ["1902-04-19T02:23:00", "Guatemala", "14.000", "-91.000", 0.0, 7.5, null, null, null, 2000.0, 2000.0, null, 2000.0, "Mw", 1902], ["1902-08-22T03:00:00", "China", "40.000", "77.000", 0.0, 7.7, null, null, null, 5650.0, null, null, 5650.0, "Mw", 1902], ["1902-09-19T00:00:00", "Australia", "-35.000", "138.000", 2.0, 6.0, null, null, null, 2.0, null, null, 2.0, "ML", 1902], ["1902-12-16T05:07:00", "Uzbekistan", "40.800", "72.300", 9.0, 6.4, null, null, null, 4725.0, null, null, 4725.0, "Muk", 1902], ["1903-03-29T22:30:00", "Palestine", "32.200", "35.300", null, 5.7, null, null, null, 20.0, null, null, 20.0, "Muk", 1903], ["1903-04-28T00:00:00", "Turkey", "39.14", "42.65", null, 7.0, null, null, null, null, null, 3500.0, 3500.0, "Ms", 1903], ["1903-05-28T03:58:00", "Turkey", "40.900", "42.700", null, 5.8, null, null, null, 1000.0, null, null, 1000.0, "Muk", 1903], ["1903-08-11T04:32:00", "Greece", "36.360", "22.970", 80.0, 8.3, null, null, null, 2.0, null, null, 2.0, "Muk", 1903], ["1903-09-25T01:20:00", "Iran", "35.200", "58.200", null, 6.5, null, null, null, 200.0, null, null, 200.0, "Muk", 1903], ["1904-04-24T06:39:00", "Taiwan", "23.500", "120.500", null, 6.0, null, null, null, 3.0, null, null, 3.0, "Muk", 1904], ["1904-08-11T05:56:00", "Greece", "37.750", "27.000", 10.0, 6.2, null, null, null, 4.0, null, null, 4.0, "Muk", 1904], ["1904-08-30T11:42:00", "China", "30.000", "101.000", 0.0, 6.8, null, null, null, 565.0, null, null, 565.0, "Ms", 1904], ["1904-11-05T20:25:00", "Taiwan", "23.500", "120.300", null, 6.3, null, null, null, 145.0, null, null, 145.0, "Muk", 1904], ["1905-04-04T00:50:00", "India", "33.000", "76.000", 0.0, 7.8, null, null, null, 20000.0, 20000.0, null, 20000.0, "Mw", 1905], ["1905-06-01T04:42:00", "Albania", "42.100", "19.600", 20.0, 6.6, null, null, null, 120.0, null, null, 120.0, "Muk", 1905], ["1905-06-02T05:39:00", "Japan", "34.100", "132.500", 55.0, 7.0, null, null, null, 11.0, null, null, 11.0, "mb", 1905], ["1905-09-08T01:43:00", "Italy", "39.000", "16.000", 0.0, 6.8, "T", null, null, 557.0, 2500.0, null, 2500.0, "Ms", 1905], ["1906-01-31T15:36:00", "Ecuador", "1.000", "-81.500", 0.0, 8.8, "T", null, null, 1000.0, 400.0, null, 1000.0, "Muk", 1906], ["1906-03-16T22:42:00", "Taiwan", "23.600", "120.400", 5.0, 6.8, null, null, null, 1258.0, null, null, 1258.0, "Ms", 1906], ["1906-04-13T19:18:00", "Taiwan", "23.600", "120.400", 5.0, 7.1, null, null, null, 15.0, null, null, 15.0, "MJMA", 1906], ["1906-04-18T13:12:00", "United States", "38.000", "-123.000", 0.0, 7.8, "F", null, null, 700.0, 2000.0, null, 2000.0, "Muk", 1906], ["1906-08-17T00:40:00", "Chile", "-33.000", "-72.000", 0.0, 8.2, "T", null, null, 3760.0, 20000.0, null, 20000.0, "Muk", 1906], [" ...

# %%
fig = px.histogram(wiki, x="magnitude", histfunc='count',title='Distribution of Earthquakes by Magnitude')
fig.show()
# Out:
# <div>                            <div id="cdc7a3e9-925c-4bef-b1dd-286b14b02a94" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cdc7a3e9-925c-4bef-b1dd-286b14b02a94")) {                    Plotly.newPlot(                        "cdc7a3e9-925c-4bef-b1dd-286b14b02a94",                        [{"alignmentgroup": "True", "bingroup": "x", "histfunc": "count", "hovertemplate": "magnitude=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [7.0, 5.9, 7.7, 6.5, 6.4, 7.2, 6.8, 6.9, 6.9, 5.5, 7.5, 6.7, 7.7, 6.0, 6.4, 5.7, 7.0, 5.8, 8.3, 6.5, 6.0, 6.2, 6.8, 6.3, 7.8, 6.6, 7.0, 6.8, 6.8, 8.8, 6.8, 7.1, 7.8, 8.2, 7.2, 7.5, 6.5, 7.9, 7.1, 7.2, 6.8, 7.2, 5.8, 7.3, 6.8, 7.1, 6.6, 6.5, 7.2, 6.2, 6.7, 7.0, 7.5, 6.8, 6.9, 7.6, 6.4, 7.8, 7.2, 6.7, 7.6, 8.1, 6.8, 7.0, 7.7, 7.6, 6.7, 7.9, 6.8, 7.8, 6.3, 7.2, 6.7, 7.0, 4.9, 7.9, 7.6, 7.2, 7.1, 6.9, 7.2, 6.2, 7.4, 7.0, 7.2, 6.0, 6.5, 6.6, 6.5, 6.4, 7.3, 7.1, 7.2, 6.8, 8.2, 7.6, 7.3, 7.6, 7.9, 6.2, 6.2, 5.8, 8.6, 6.0, null, 7.3, 6.8, 7.5, 6.9, 8.7, 6.9, 6.5, 8.5, 7.2, 7.1, 5.7, 7.9, 7.1, 6.4, 6.9, 5.3, 7.3, 6.9, 8.3, 7.1, 6.8, 6.8, 7.0, 6.8, 6.2, 5.5, 5.5, 6.9, 7.7, 6.8, 5.7, 7.1, 7.6, 5.0, 7.2, 7.9, 6.3, 6.8, 7.5, 6.5, 6.8, 6.8, 6.8, 7.2, 5.4, 7.7, 7.3, 6.9, 7.1, 6.5, 6.8, 7.5, 5.8, 7.4, 7.3, 7.2, 7.1, 6.0, 6.6, 6.0, 6.0, 6.9, 5.0, 7.3, 6.3, 6.0, 7.0, 7.8, 7.7, 7.1, 6.8, 5.6, 6.3, 6.1, 7.9, 7.1, 6.8, 7.8, 7.5, 6.8, 6.8, 6.0, 8.1, 6.9, 7.9, 7.9, 6.9, 6.9, 7.6, 8.4, 6.4, 6.8, 7.3, 7.3, 6.3, 6.0, 8.1, 6.2, 6.8, 6.0, 6.8, 7.1, 6.0, 6.2, 8.1, 6.3, 7.0, 6.8, 6.8, 6.8, 6.0, 5.5, 7.1, 7.2, 6.9, 7.3, 7.4, 6.8, 7.5, 7.9, 7.7, 7.9, 7.0, 6.4, 5.5, 7.8, 6.0, 6.0, 6.9, 7.5, 5.5, 7.5, 7.3, 5.9, 6.3, 7.6, 6.0, 6.9, 7.7, 6.0, 6.0, 5.9, 7.7, 7.1, 7.0, 6.8, 7.8, 7.7, 7.7, 6.0, 7.2, 6.6, 7.4, 8.2, 6.2, 7.6, 7.0, 7.5, 6.5, 7.1, 7.2, 7.1, 4.8, 6.8, 8.1, 6.8, 7.1, 6.0, 7.0, 6.3, 8.0, 6.0, 5.6, 7.3, 5.9, 7.6, 7.1, 7.9, 7.3, 7.1, 6.8, 6.6, 8.1, 5.5, 6.8, 7.4, 6.9, 7.7, 8.1, 7.4, 7.2, 7.0, 6.9, 6.8, 7.0, 6.4, 6.9, 7.2, 5.8, 6.9, 7.3, 6.5, 7.1, 7.6, 6.8, 6.8, 6.8, 7.8, 7.8, 7.2, 6.0, 6.8, 6.8, 8.6, 7.7, 6.2, 6.7, 7.5, 7.3, 6.0, 8.1, 6.5, 6.8, 7.3, 7.7, 5.8, 5.0, 9.0, 5.7, 6.4, 7.2, 7.5, 7.2, 6.5, 6.8, 7.5, 7.1, 6.8, 6.8, 5.0, 6.7, 7.7, 7.5, 7.1, 6.9, 6.0, 6.8, 6.7, 5.8, 6.9, 5.8, 5.8, 5.8, 7.6, 7.8, 7.1, 6.1, 6.9, 6.8, 5.6, 7.2, 6.9, 7.0, 7.2, 7.1, 7.8, 8.1, 6.8, 7.0, 7.8, 6.8, 7.2, 6.8, 7.3, 6.7, 6.8, 6.7, 7.5, 8.0, 7.0, 7.5, 7.2, 7.3, 6.9, 6.1, 7.5, 6.9, 5.6, 5.7, 6.0, 6.8, 9.5, 6.6, 7.8, 7.7, 6.6, 6.8, 6.9, 6.9, 6.7, 7.3, 6.7, 6.9, 6.8, 6.9, 7.3, 6.7, 6.9, 6.1, 5.5, 6.4, 9.2, 5.6, 6.3, 5.5, 7.5, 7.2, 6.0, 8.2, 6.5, 5.6, 7.4, 6.3, 5.6, 6.5, 5.8, 7.4, 7.0, 6.2, 5.6, 6.6, 7.4, 7.2, 5.6, 5.0, 6.0, 7.0, 5.6, 5.8, 5.8, 8.2, 5.7, 7.7, 7.2, 5.9, 5.5, 6.1, 5.9, 7.4, 5.6, 5.9, 6.5, 7.0, 7.0, 5.8, 6.3, 7.4, 6.4, 7.2, 7.5, 8.3, 7.2, 6.9, 5.7, 7.7, 7.3, 7.3, 7.2, 6.3, 5.7, 6.2, 5.8, 7.1, 5.9, 7.8, 6.4, 6.3, 6.8, 7.2, 5.9, 6.0, 6.3, 6.2, 5.7, 5.6, 6.1, 7.2, 6.4, 6.6, 7.4, 7.2, 5.5, 6.5, 7.9, 6.6, 6.6, 8.0, 7.3, 6.1, 7.1, 6.7, 5.6, 5.9, 6.3, 5.9, 6.7, 7.2, 7.8, 8.0, 5.8, 7.3, 5.5, 5.7, 5.7, 6.3, 7.5, 6.9, 6.7, 6.9, 6.1, 6.2, 6.2, 7.5, 7.7, 7.5, 6.5, 6.6, 6.4, 7.2, 5.5, 5.2, 5.1, 6.6, 5.4, 5.5, 6.7, 6.8, 6.5, 7.3, 5.6, 5.7, 8.1, 6.2, 6.8, 7.0, 5.6, 6.1, 6.9, 6.3, 6.5, 4.3, 5.3, 6.7, 7.6, 5.0, 7.2, 4.6, 5.5, 6.3, 7.5, 5.4, 5.9, 5.4, 5.6, 4.8, 4.6, 5.5, 6.6, 5.5, 6.5, 6.7, 6.7, 6.7, 6.6, 7.1, 4.2, 6.5, 6.1, 7.6, 7.0, 6.7, 8.0, 7.1, 5.0, 6.4, 5.5, 6.0, 5.9, 5.7, 6.8, 6.3, 6.0, 7.0, 7.5, 5.2, 5.9, 6.0, 7.5, 7.2, 6.7, 5.3, 6.0, 7.3, 5.6, 5.7, 8.3, 7.0, 6.5, 7.4, 5.6, 5.9, 6.6, 6.3, 5.2, 6.1, 6.6, 6.0, 5.7, 7.6, 5.3, 6.5, 4.6, 4.9, 7.4, 7.8, 6.1, 7.0, 6.5, 7.1, 7.4, 6.0, 6.9, 6.2, ...

# %%
fig = px.histogram(wiki, x="country", histfunc='count',title='Distribution of Earthquakes by Country')
fig.show()
# Out:
# <div>                            <div id="83abeeb6-8d86-4386-9195-85fb3d4a1e46" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("83abeeb6-8d86-4386-9195-85fb3d4a1e46")) {                    Plotly.newPlot(                        "83abeeb6-8d86-4386-9195-85fb3d4a1e46",                        [{"alignmentgroup": "True", "bingroup": "x", "histfunc": "count", "hovertemplate": "country=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": ["Turkey", "Bulgaria", "New Zealand", "Japan", "Azerbaijan", "Turkey", "Guatemala", "China", "Australia", "Uzbekistan", "Palestine", "Turkey", "Turkey", "Greece", "Iran", "Taiwan", "Greece", "China", "Taiwan", "India", "Albania", "Japan", "Italy", "Ecuador", "Taiwan", "Taiwan", "United States", "Chile", "China", "Indonesia", "Jamaica", "Mexico", "Philippines", "Tajikistan", "Taiwan", "Italy", "Turkey", "Iran", "Taiwan", "Portugal", "China", "Indonesia", "France", "Japan", "Pakistan", "Japan", "China", "Greece", "Japan", "Algeria", "Kazakhstan", "Kyrgyzstan", "Iran", "Mexico", "Japan", "Iceland", "Turkey", "Mexico", "Bulgaria", "Peru", "China", "Japan", "Japan", "Italy", "Indonesia", "Turkey", "Italy", "Japan", "United States", "El Salvador", "China", "Taiwan", "Taiwan", "Taiwan", "Indonesia", "Philippines", "China", "China", "United States", "Philippines", "Russian Federation", "Puerto Rico", "Taiwan", "Mexico", "Georgia", "Italy", "China", "Argentina", "Philippines", "Japan", "Taiwan", "Taiwan", "Chile", "Japan", "China", "Russian Federation", "Iran", "Japan", "Bangladesh", "Iran", "Iran", "Colombia", "Japan", "Ecuador", "China", "Kyrgyzstan", "Turkey", "China", "Japan", "United States", "Iran", "Iran", "Greece", "Indonesia", "Turkey", "Japan", "China", "Argentina", "China", "Palestine", "Taiwan", "Turkey", "Peru", "Bulgaria", "Bulgaria", "Peru", "Iran", "Chile", "Philippines", "Turkmenistan", "Turkey", "Argentina", "New Zealand", "Iran", "Saint Pierre and Miquelon", "Myanmar", "Iran", "China", "Italy", "Italy", "Albania", "Japan", "Albania", "Myanmar", "Taiwan", "Argentina", "Japan", "Mexico", "New Zealand", "Indonesia", "Yugoslavia", "Nicaragua", "Armenia", "England", "China", "Pakistan", "Japan", "Solomon Islands", "Japan", "Cuba", "Venezuela", "China", "Indonesia", "Nicaragua", "Mexico", "Mexico", "Mexico", "Greece", "China", "Japan", "United States", "Greece", "Indonesia", "China", "Iran", "China", "Nepal", "Turkey", "Iran", "Iran", "Taiwan", "China", "Turkey", "Pakistan", "Japan", "Colombia", "China", "China", "China", "China", "Indonesia", "Mexico", "China", "Philippines", "Mexico", "Turkey", "Indonesia", "Japan", "Chile", "Solomon Islands", "Japan", "Ghana", "China", "Turkey", "China", "Georgia", "United States", "Peru", "China", "Japan", "Romania", "Yemen", "Iran", "Mexico", "China", "China", "Turkey", "China", "Turkey", "Japan", "Taiwan", "China", "Ecuador", "Guatemala", "Peru", "Albania", "Turkey", "Turkey", "Mexico", "Chile", "Turkey", "Indonesia", "Japan", "Turkey", "Taiwan", "Argentina", "Turkey", "China", "Iran", "Turkey", "Japan", "Japan", "Japan", "Turkey", "Chile", "China", "Pakistan", "Algeria", "Turkey", "United States", "Turkey", "Canada", "Chile", "Dominican Republic", "Turkmenistan", "Peru", "Taiwan", "Japan", "China", "Iran", "Japan", "Peru", "Philippines", "Peru", "China", "Peru", "Japan", "China", "Japan", "Greece", "Argentina", "Turkmenistan", "China", "Mexico", "China", "United States", "Chile", "Tajikistan", "Turkey", "Ecuador", "Turkey", "Chile", "Chile", "Philippines", "Peru", "Indonesia", "Venezuela", "China", "Chile", "Mexico", "Turkey", "Taiwan", "Taiwan", "Turkey", "Japan", "Argentina", "Japan", "Uni ...
